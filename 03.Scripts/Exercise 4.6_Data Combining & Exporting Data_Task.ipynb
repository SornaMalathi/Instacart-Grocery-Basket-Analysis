# %% [markdown]
# # Exercise 4.6_Data Combining and Exporting Dataframes
#
# The following steps are performed in this Notebook
# 1. Import the Dataframes to be merged. We have imported the orders_products_combined dataframe in PICKLE format and products_cleaned Dataframe in CSV format
# 2. Check the shape of both the Dataframes
# 3. Combine the two Dataframes using the suitable MERGE command
# 4. Confirm the results of the merge using the '_merge' count and also merge the Dataframe using how = outer and check for the counts
# 5. Export the combined Dataframe in PICKLE format

# %% [markdown]
# #Import Dataframes

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Import the pickle format df_orders_products_combined Dataframe

# %%
path = r'C:\Users\sorna\Desktop\Data Analysis\Achievement 4'

# %%
df_orders_products_combined = pd.read_pickle(os.path.join(path, '02.Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %%
df_orders_products_combined.shape
# Out:
# (32434489, 11)

# %% [markdown]
# # Import the cleaned Products Dataframe

# %%
df_prods_cleaned = pd.read_csv(os.path.join(path, '02.Data', 'Prepared Data', 'product_cleaned.csv'), index_col = False)

# %%
df_prods_cleaned.shape
# Out:
# (49672, 6)

# %%
df_orders_products_combined
# Out:
#           order_id  user_id eval_set  order_number  order_dow  \
# 0          2539329        1    prior             1          2
# 1          2539329        1    prior             1          2
# 2          2539329        1    prior             1          2
# 3          2539329        1    prior             1          2
# 4          2539329        1    prior             1          2
# ...            ...      ...      ...           ...        ...
# 32434484   2977660   206209    prior            13          1
# 32434485   2977660   206209    prior            13          1
# 32434486   2977660   206209    prior            13          1
# 32434487   2977660   206209    prior            13          1
# 32434488   2977660   206209    prior            13          1
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     NaN         196
# 1                         8                     NaN       14084
# ...

# %% [markdown]
# # Drop the merge column from the Dataframe inorder to perform the merge function to these Dataframes using the indicator = True arguement

# %%
df_orders_products_combined = df_orders_products_combined.drop(['_merge'], axis = 1)

# %%
df_orders_products_combined
# Out:
#           order_id  user_id eval_set  order_number  order_dow  \
# 0          2539329        1    prior             1          2
# 1          2539329        1    prior             1          2
# 2          2539329        1    prior             1          2
# 3          2539329        1    prior             1          2
# 4          2539329        1    prior             1          2
# ...            ...      ...      ...           ...        ...
# 32434484   2977660   206209    prior            13          1
# 32434485   2977660   206209    prior            13          1
# 32434486   2977660   206209    prior            13          1
# 32434487   2977660   206209    prior            13          1
# 32434488   2977660   206209    prior            13          1
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     NaN         196
# 1                         8                     NaN       14084
# ...

# %%
df_prods_cleaned
# Out:
#        Unnamed: 0  product_id  \
# 0               0           1
# 1               1           2
# 2               2           3
# 3               3           4
# 4               4           5
# ...           ...         ...
# 49667       49688       49684
# 49668       49689       49685
# 49669       49690       49686
# 49670       49691       49687
# 49671       49692       49688
#
#                                             product_name  aisle_id  \
# 0                             Chocolate Sandwich Cookies        61
# 1                                       All-Seasons Salt       104
# 2                   Robust Golden Unsweetened Oolong Tea        94
# 3      Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4                              Green Chile Anytime Sauce         5
# ...                                                  ...       ...
# 49667          Vodka, Triple Distilled, Twist of Vanilla       124
# ...

# %% [markdown]
# # Merge the two Dataframes using the INNER join and using the product_id as the key column.

# %%
df_ords_prods_merged = df_prods_cleaned.merge(df_orders_products_combined, on = 'product_id', indicator = True)

# %%
df_ords_prods_merged.shape
# Out:
# (32404859, 16)

# %%
df_ords_prods_merged['_merge'].value_counts()
# Out:
# _merge
# both          32404859
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %% [markdown]
# # Created a new Dataframe using the OUTER join arguement to cross check the merged Dataframe.

# %%
df_ords_prods_merged_1 = df_prods_cleaned.merge(df_orders_products_combined, on = 'product_id', indicator = True, how = 'outer')

# %%
df_ords_prods_merged_1.shape
# Out:
# (32435070, 16)

# %%
df_ords_prods_merged_1['_merge'].value_counts()
# Out:
# _merge
# both          32404859
# right_only       30200
# left_only           11
# Name: count, dtype: int64

# %% [markdown]
# # Export the merged Dataframe in the pickle format

# %%
df_ords_prods_merged.to_pickle(os.path.join(path, '02.Data','Prepared Data', 'ords_prods_merged.pkl'))
