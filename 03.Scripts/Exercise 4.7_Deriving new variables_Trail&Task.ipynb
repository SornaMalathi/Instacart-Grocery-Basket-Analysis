# %% [markdown]
# # Exercise 4.7:- Deriving new variable
# This notebook has the steps given in Exercise 4.7 for practise along with tasks given in 4.7.
# 1. Derived a new columns named price_range_loc, Busiest_day, Busiest_days, Busiest_period_of_day
# 2. Export the Dataset with all the new derived columns as 'orders_products_new_variables'.

# %% [markdown]
# # Import Dataframes

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Import the ords_prods_merged Dataframe

# %%
path = r'C:\Users\sorna\Desktop\Data Analysis\Achievement 4'

# %%
df_ords_prods_merged = pd.read_pickle(os.path.join(path, '02.Data', 'Prepared Data', 'ords_prods_merged.pkl'))

# %% [markdown]
# # Create a subset of the Dataframe to have only 1M records to avoid memory shortage issue

# %%
df = df_ords_prods_merged[:1000000]

# %%
df
# Out:
#         Unnamed: 0  product_id                product_name  aisle_id  \
# 0                0           1  Chocolate Sandwich Cookies        61
# 1                0           1  Chocolate Sandwich Cookies        61
# 2                0           1  Chocolate Sandwich Cookies        61
# 3                0           1  Chocolate Sandwich Cookies        61
# 4                0           1  Chocolate Sandwich Cookies        61
# ...            ...         ...                         ...       ...
# 999995        2078        2078  Unsalted Pure Irish Butter        36
# 999996        2078        2078  Unsalted Pure Irish Butter        36
# 999997        2078        2078  Unsalted Pure Irish Butter        36
# 999998        2078        2078  Unsalted Pure Irish Butter        36
# 999999        2078        2078  Unsalted Pure Irish Butter        36
#
#         department_id  prices  order_id  user_id eval_set  order_number  \
# ...

# %%
# Define the function

def price_label(row):
    if row['prices'] <= 5:
        return 'low-range product'
    elif (row['prices'] < 5) and (row['prices'] >= 15):
        return 'mid-range product'
    elif row['prices'] > 15:
        return 'high-range product'
    else: return 'Not enough Data'

# %%
df.shape
# Out:
# (1000000, 16)

# %%
# Apply the function
df['price_range'] = df.apply(price_label, axis = 1)
# Out:
# C:\Users\sorna\AppData\Local\Temp\ipykernel_19540\2004007646.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis = 1)

# %%
df['price_range'].value_counts(dropna = False)
# Out:
# price_range
# Not enough Data       652638
# low-range product     338018
# high-range product      9344
# Name: count, dtype: int64

# %%
df['prices'].max()
# Out:
# 24.5

# %%
# Using loc() instead of if-else statement
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# C:\Users\sorna\AppData\Local\Temp\ipykernel_19540\2682916268.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df['price_range_loc'].value_counts(dropna = False)
# Out:
# price_range_loc
# Mid-range product     652638
# Low-range product     338018
# High-range product      9344
# Name: count, dtype: int64

# %% [markdown]
# # Repeat it for the complete Dataframe instead of the subset

# %%
df_ords_prods_merged.loc[df_ords_prods_merged['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df_ords_prods_merged.loc[(df_ords_prods_merged['prices'] <= 15) & (df_ords_prods_merged['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df_ords_prods_merged.loc[df_ords_prods_merged['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df_ords_prods_merged['price_range_loc'].value_counts(dropna = False)
# Out:
# price_range_loc
# Mid-range product     21860860
# Low-range product     10126321
# High-range product      417678
# Name: count, dtype: int64

# %% [markdown]
# # To find which day of the week is having the maximum orders

# %%
df_ords_prods_merged['order_dow'].value_counts(dropna = False)
# Out:
# order_dow
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: count, dtype: int64

# %% [markdown]
# # Use the For-loop to mark the DOW with the specific string indicating the busy DOW

# %%
result = []

for value in df_ords_prods_merged["order_dow"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Busiest day',
#  'Least busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %% [markdown]
# # this is a big list, lets assign the values in the Dataframe itself

# %%
df_ords_prods_merged['busiest_day'] = result

# %%
df_ords_prods_merged['busiest_day'].value_counts(dropna = False)
# Out:
# busiest_day
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: count, dtype: int64

# %% [markdown]
# # Exercise 4.7_ Deriving new Variables _ Task

# %% [markdown]
# # Find the busiest days

# %%
df_ords_prods_merged['order_dow'].value_counts(dropna = False)
# Out:
# order_dow
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: count, dtype: int64

# %% [markdown]
# # Saturday and Sunday are the 2 most busiest days and tuesday and Wednesday are the 2 slowest days of the week.
# # Use the for-loop to assign a specific string to the busiest and slowest days of the week

# %%
result = []

for value in df_ords_prods_merged["order_dow"]:
  if value == 0 or value == 1:
    result.append("Busiest day")
  elif value == 3 or value == 4:
    result.append("slowest day")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'slowest day',
#  'slowest day',
#  'Busiest day',
#  'Regularly busy',
#  'slowest day',
#  'Busiest day',
#  'Busiest day',
#  'Regularly busy',
#  'slowest day',
#  'slowest day',
#  'Regularly busy',
#  'slowest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Busiest day',
#  'Regularly busy',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'slowest day',
#  'Regularly busy',
#  'Busiest day',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'slowest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'slowest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'slowest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'slowest day',
#  'Regularly busy',
# ...

# %%
df_ords_prods_merged['Busiest days'] = result

# %%
df_ords_prods_merged['Busiest days'].value_counts(dropna = False)
# Out:
# Busiest days
# Regularly busy    12916111
# Busiest day       11864412
# slowest day        7624336
# Name: count, dtype: int64

# %%
df_ords_prods_merged['order_dow'].value_counts(dropna = False)
# Out:
# order_dow
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: count, dtype: int64

# %% [markdown]
# # The sum of 0 and 1 is Busiest day count and sum of 3 and 4 is slowest Day.

# %%
df_ords_prods_merged
# Out:
#           Unnamed: 0  product_id                product_name  aisle_id  \
# 0                  0           1  Chocolate Sandwich Cookies        61
# 1                  0           1  Chocolate Sandwich Cookies        61
# 2                  0           1  Chocolate Sandwich Cookies        61
# 3                  0           1  Chocolate Sandwich Cookies        61
# 4                  0           1  Chocolate Sandwich Cookies        61
# ...              ...         ...                         ...       ...
# 32404854       49692       49688      Fresh Foaming Cleanser        73
# 32404855       49692       49688      Fresh Foaming Cleanser        73
# 32404856       49692       49688      Fresh Foaming Cleanser        73
# 32404857       49692       49688      Fresh Foaming Cleanser        73
# 32404858       49692       49688      Fresh Foaming Cleanser        73
#
#           department_id  prices  order_id  user_id eval_set  order_number  \
# ...

# %%
df_ords_prods_merged['order_hour_of_day'].value_counts(dropna = False)
# Out:
# order_hour_of_day
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: count, dtype: int64

# %%
result1 = []

for value in df_ords_prods_merged["order_hour_of_day"]:
  if value >= 8 and value <= 17:
    result1.append("Most orders")
  elif value >= 18 or value <= 23:
    result1.append("average orders")
  else:
    result1.append("Fewest orders")

# %%
result1
# Out:
# ['Most orders',
#  'Most orders',
#  'average orders',
#  'Most orders',
#  'Most orders',
#  'average orders',
#  'Most orders',
#  'Most orders',
#  'average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'average orders',
#  'average orders',
#  'average orders',
#  'average orders',
#  'average orders',
#  'average orders',
#  'average orders',
#  'average orders',
#  'Most orders',
#  'Most orders',
#  'average orders',
#  'average orders',
#  'average orders',
#  'average orders',
#  'average orders',
#  'average orders',
#  'average orders',
#  'average orders',
#  'average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'average orders',
#  'Most orders',
#  'average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
# ...

# %%
df_ords_prods_merged['busiest_period_of_day'] = result1

# %%
df_ords_prods_merged['busiest_period_of_day'].value_counts(dropna = False)
# Out:
# busiest_period_of_day
# Most orders       24923843
# average orders     7481016
# Name: count, dtype: int64

# %%
df_ords_prods_merged['order_hour_of_day'].value_counts(dropna = False)
# Out:
# order_hour_of_day
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: count, dtype: int64

# %% [markdown]
# # The duration between 8 to 17 hours has the most orders, duration between 18 to 23 hours has the average order and rest of the day has the Fewest orders. This has been crossed checked using the frequency check of the order_hour_of_day variable.

# %%
df_ords_prods_merged
# Out:
#           Unnamed: 0  product_id                product_name  aisle_id  \
# 0                  0           1  Chocolate Sandwich Cookies        61
# 1                  0           1  Chocolate Sandwich Cookies        61
# 2                  0           1  Chocolate Sandwich Cookies        61
# 3                  0           1  Chocolate Sandwich Cookies        61
# 4                  0           1  Chocolate Sandwich Cookies        61
# ...              ...         ...                         ...       ...
# 32404854       49692       49688      Fresh Foaming Cleanser        73
# 32404855       49692       49688      Fresh Foaming Cleanser        73
# 32404856       49692       49688      Fresh Foaming Cleanser        73
# 32404857       49692       49688      Fresh Foaming Cleanser        73
# 32404858       49692       49688      Fresh Foaming Cleanser        73
#
#           department_id  prices  order_id  user_id eval_set  order_number  \
# ...

# %%
df_ords_prods_merged.to_pickle(os.path.join(path, '02.Data','Prepared Data', 'orders_products_new_variables.pkl'))
