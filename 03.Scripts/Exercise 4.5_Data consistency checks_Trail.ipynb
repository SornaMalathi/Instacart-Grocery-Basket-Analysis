# %% [markdown]
# # Exercise 4.5:- Data Consistency check
#
# Both the orders and Products dataset are checked for Data consistencies
# 1. Checked for missing values, duplicate records, mixed Data type.
# 2. Both orders and products datasets are exported back to the local Prepared Data Folder

# %% [markdown]
# #01 Importing Libraries

# %%
#import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Import the products Dataset and orders dataset after the wrangling step.

# %%
path = r'C:\Users\sorna\Desktop\Data Analysis\Achievement 4'

# %%
df_prods = df = pd.read_csv(os.path.join(path, '02.Data', 'Original Data', 'products.csv'), index_col = False)

# %%
df_ords = df = pd.read_csv(os.path.join(path, '02.Data', 'Prepared Data', 'orders_wrangled.csv'), index_col = False)

# %%
df_ords.describe()
# Out:
#          Unnamed: 0      order_id       user_id  order_number  \
# count  3.421083e+06  3.421083e+06  3.421083e+06  3.421083e+06
# mean   1.710541e+06  1.710542e+06  1.029782e+05  1.715486e+01
# std    9.875817e+05  9.875817e+05  5.953372e+04  1.773316e+01
# min    0.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    8.552705e+05  8.552715e+05  5.139400e+04  5.000000e+00
# 50%    1.710541e+06  1.710542e+06  1.026890e+05  1.100000e+01
# 75%    2.565812e+06  2.565812e+06  1.543850e+05  2.300000e+01
# max    3.421082e+06  3.421083e+06  2.062090e+05  1.000000e+02
#
#        orders_day_of_the_week  order_hour_of_day  days_since_prior_order
# count            3.421083e+06       3.421083e+06            3.214874e+06
# mean             2.776219e+00       1.345202e+01            1.111484e+01
# std              2.046829e+00       4.226088e+00            9.206737e+00
# min              0.000000e+00       0.000000e+00            0.000000e+00
# ...

# %% [markdown]
# # 01 Creating a test dataframe for learning mixed data types

# %%
#create a dataframe
df_test = pd.DataFrame()

# %%
# create a mixed type column
df_test['mix'] = ['a', 'b', 1, True]

# %%
df_test.head()
# Out:
#     mix
# 0     a
# 1     b
# 2     1
# 3  True

# %%
for col in df_test.columns.tolist():
    weird = (df_test[[col]].applymap(type) != df_test[[col]].iloc[0].apply(type)).any(axis = 1)
    if len (df_test[weird]) > 0:
       print (col)
# Out:
# mix
# C:\Users\sorna\AppData\Local\Temp\ipykernel_26156\1412710303.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_test[[col]].applymap(type) != df_test[[col]].iloc[0].apply(type)).any(axis = 1)

# %%
df_test['mix'] = df_test['mix'].astype('str')

# %%
df_test['mix'].dtype
# Out:
# dtype('O')

# %% [markdown]
# # 02 FIND THE NUMBER OF MISSING VALUES IN EACH COLUMN IN THE DATAFRAME

# %%
df_prods.isnull().sum()
# Out:
# product_id        0
# product_name     16
# aisle_id          0
# department_id     0
# prices            0
# dtype: int64

# %% [markdown]
# # 03 CREATE A NEW DATAFRAME WITH THE RECORDS HAVING MISSING VALUES

# %%
df_nan = df_prods[df_prods['product_name'].isnull() == True]

# %%
df_nan.head()
# Out:
#      product_id product_name  aisle_id  department_id  prices
# 33           34          NaN       121             14    12.2
# 68           69          NaN        26              7    11.8
# 115         116          NaN        93              3    10.8
# 261         262          NaN       110             13    12.1
# 525         525          NaN       109             11     1.2

# %%
df_nan
# Out:
#        product_id product_name  aisle_id  department_id  prices
# 33             34          NaN       121             14    12.2
# 68             69          NaN        26              7    11.8
# 115           116          NaN        93              3    10.8
# 261           262          NaN       110             13    12.1
# 525           525          NaN       109             11     1.2
# 1511         1511          NaN        84             16    14.3
# 1780         1780          NaN       126             11    12.3
# 2240         2240          NaN        52              1    14.2
# 2586         2586          NaN       104             13    12.4
# 3159         3159          NaN       126             11    13.1
# 3230         3230          NaN       120             16    14.4
# 3736         3736          NaN        41              8    14.8
# 4283         4283          NaN        77              7    14.4
# 4790         4790          NaN        91             16    14.5
# ...

# %%
df_prods.shape
# Out:
# (49693, 5)

# %%
df_nan = df_prods[df_prods['product_name'].isnull() == True]

# %% [markdown]
# # 04 CREATE A NEW DATAFRAME DROPPING THE RECORDS WITH THE MISSING VALUES

# %%
df_prods_clean = df_prods[df_prods['product_name'].isnull() == False]

# %%
df_prods_clean
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49688       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49689       49685                 En Croute Roast Hazelnut Cranberry
# 49690       49686                                   Artisan Baguette
# 49691       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49692       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19     5.8
# 1           104             13     9.3
# ...

# %% [markdown]
# # 05 CHECK FOR DULICATE RECORDS

# %%
df_dups = df_prods_clean[df_prods_clean.duplicated()]

# %%
df_dups
# Out:
#        product_id                                       product_name  \
# 462           462                  Fiber 4g Gummy Dietary Supplement
# 18459       18458                                         Ranger IPA
# 26810       26808               Black House Coffee Roasty Stout Beer
# 35309       35306  Gluten Free Organic Peanut Butter & Chocolate ...
# 35495       35491                            Adore Forever Body Wash
#
#        aisle_id  department_id  prices
# 462          70             11     4.8
# 18459        27              5     9.2
# 26810        27              5    13.4
# 35309       121             14     6.8
# 35495       127             11     9.9

# %% [markdown]
# # 06 MOVE UNIQUE RECORDS TO A NEW DATAFRAME

# %%
df_prods_clean_no_dups = df_prods_clean.drop_duplicates()

# %%
df_prods_clean_no_dups
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49688       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49689       49685                 En Croute Roast Hazelnut Cranberry
# 49690       49686                                   Artisan Baguette
# 49691       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49692       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19     5.8
# 1           104             13     9.3
# ...

# %% [markdown]
# # 07 EXPORT THE CONSISTENCY CHECKED PRODUCT DATAFRAME TO THE PREPARED DATA FOLDER

# %%
df_prods_clean_no_dups.to_csv(os.path.join(path, '02.Data', 'Prepared data', 'product_checked.csv'))

# %%
df_ords.describe()
# Out:
#          Unnamed: 0      order_id       user_id  order_number  \
# count  3.421083e+06  3.421083e+06  3.421083e+06  3.421083e+06
# mean   1.710541e+06  1.710542e+06  1.029782e+05  1.715486e+01
# std    9.875817e+05  9.875817e+05  5.953372e+04  1.773316e+01
# min    0.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    8.552705e+05  8.552715e+05  5.139400e+04  5.000000e+00
# 50%    1.710541e+06  1.710542e+06  1.026890e+05  1.100000e+01
# 75%    2.565812e+06  2.565812e+06  1.543850e+05  2.300000e+01
# max    3.421082e+06  3.421083e+06  2.062090e+05  1.000000e+02
#
#        orders_day_of_the_week  order_hour_of_day  days_since_prior_order
# count            3.421083e+06       3.421083e+06            3.214874e+06
# mean             2.776219e+00       1.345202e+01            1.111484e+01
# std              2.046829e+00       4.226088e+00            9.206737e+00
# min              0.000000e+00       0.000000e+00            0.000000e+00
# ...

# %%
df_ords.shape
# Out:
# (3421083, 7)

# %% [markdown]
# # TASK
# # 01 df.describe on df_ords dataframe

# %%
df_ords.describe()
# Out:
#          Unnamed: 0      order_id       user_id  order_number  \
# count  3.421083e+06  3.421083e+06  3.421083e+06  3.421083e+06
# mean   1.710541e+06  1.710542e+06  1.029782e+05  1.715486e+01
# std    9.875817e+05  9.875817e+05  5.953372e+04  1.773316e+01
# min    0.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    8.552705e+05  8.552715e+05  5.139400e+04  5.000000e+00
# 50%    1.710541e+06  1.710542e+06  1.026890e+05  1.100000e+01
# 75%    2.565812e+06  2.565812e+06  1.543850e+05  2.300000e+01
# max    3.421082e+06  3.421083e+06  2.062090e+05  1.000000e+02
#
#        orders_day_of_the_week  order_hour_of_day  days_since_prior_order
# count            3.421083e+06       3.421083e+06            3.214874e+06
# mean             2.776219e+00       1.345202e+01            1.111484e+01
# std              2.046829e+00       4.226088e+00            9.206737e+00
# min              0.000000e+00       0.000000e+00            0.000000e+00
# ...

# %% [markdown]
# # The maximum order_number is 100.
# # The max and min value for orders_day_of_the_week is 0 and 6, this represents 0 for Monday and 6 for Sunday. In total of 7 days of the week.
# # The count of the days_since_prior_order is lower compared to the other columns. There could be missing values in this column

# %% [markdown]
# # 02 CHECK FOR MIXED DATA TYPES

# %%
for col in df_ords.columns.tolist():
    weird = (df_ords[[col]].applymap(type) != df_ords[[col]].iloc[0].apply(type)).any(axis = 1)
    if len (df_ords[weird]) > 0:
       print (col)
# Out:
# C:\Users\sorna\AppData\Local\Temp\ipykernel_8276\2710567795.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_ords[[col]].applymap(type) != df_ords[[col]].iloc[0].apply(type)).any(axis = 1)
# C:\Users\sorna\AppData\Local\Temp\ipykernel_8276\2710567795.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_ords[[col]].applymap(type) != df_ords[[col]].iloc[0].apply(type)).any(axis = 1)
# C:\Users\sorna\AppData\Local\Temp\ipykernel_8276\2710567795.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_ords[[col]].applymap(type) != df_ords[[col]].iloc[0].apply(type)).any(axis = 1)
# C:\Users\sorna\AppData\Local\Temp\ipykernel_8276\2710567795.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_ords[[col]].applymap(type) != df_ords[[col]].iloc[0].apply(type)).any(axis = 1)
# ...

# %% [markdown]
# # Received an error, so changed applymap to just map

# %%
for col in df_ords.columns.tolist():
    weird = (df_ords[[col]].map(type) != df_ords[[col]].iloc[0].apply(type)).any(axis = 1)
    if len (df_ords[weird]) > 0:
       print (col)

# %% [markdown]
# # There are no columns with mixed data type in the Dataframe df_ords

# %%
df_ords.dtypes
# Out:
# Unnamed: 0                  int64
# order_id                    int64
# user_id                     int64
# order_number                int64
# orders_day_of_the_week      int64
# order_hour_of_day           int64
# days_since_prior_order    float64
# dtype: object

# %% [markdown]
# # 03 CHECK FOR MISSING VALUES

# %%
df_ords.isnull().sum()
# Out:
# Unnamed: 0                     0
# order_id                       0
# user_id                        0
# order_number                   0
# orders_day_of_the_week         0
# order_hour_of_day              0
# days_since_prior_order    206209
# dtype: int64

# %% [markdown]
# # 04 ADDRESSING THE MISSING VALUES

# %% [markdown]
# # There are 206209 missing values in the column days_since_prior_order. The missing values could be for the customers during their first order. Values cannot be imputed, cannot be removed. Maybe we can introduce a new flag for 1st order.

# %% [markdown]
# # Before addressing the missing value, we need to check if the records with the missing values are having value 1 in the column 'order_number'.

# %%
df_ords_nan = df_ords[df_ords['days_since_prior_order'].isnull() == True]

# %%
df_ords_nan
# Out:
#          Unnamed: 0  order_id  user_id  order_number  orders_day_of_the_week  \
# 0                 0   2539329        1             1                       2
# 11               11   2168274        2             1                       2
# 26               26   1374495        3             1                       1
# 39               39   3343014        4             1                       6
# 45               45   2717275        5             1                       3
# ...             ...       ...      ...           ...                     ...
# 3420930     3420930    969311   206205             1                       4
# 3420934     3420934   3189322   206206             1                       3
# 3421002     3421002   2166133   206207             1                       6
# 3421019     3421019   2227043   206208             1                       1
# 3421069     3421069   3154581   206209             1                       3
#
# ...

# %%
df_ords_first_order = df_ords_nan[df_ords_nan['order_number'] == 1]

# %%
df_ords_first_order
# Out:
#          Unnamed: 0  order_id  user_id  order_number  orders_day_of_the_week  \
# 0                 0   2539329        1             1                       2
# 11               11   2168274        2             1                       2
# 26               26   1374495        3             1                       1
# 39               39   3343014        4             1                       6
# 45               45   2717275        5             1                       3
# ...             ...       ...      ...           ...                     ...
# 3420930     3420930    969311   206205             1                       4
# 3420934     3420934   3189322   206206             1                       3
# 3421002     3421002   2166133   206207             1                       6
# 3421019     3421019   2227043   206208             1                       1
# 3421069     3421069   3154581   206209             1                       3
#
# ...

# %% [markdown]
# # This shows that all records with missing values in the column days_since_prior_order are customer's first order. So these records cannot be deleted. Hence we can introduce a new flag to the dataframe.

# %%
df_ords['First_order'] = df_ords['days_since_prior_order'].isna()

# %%
df_ords
# Out:
#          Unnamed: 0  order_id  user_id  order_number  orders_day_of_the_week  \
# 0                 0   2539329        1             1                       2
# 1                 1   2398795        1             2                       3
# 2                 2    473747        1             3                       3
# 3                 3   2254736        1             4                       4
# 4                 4    431534        1             5                       4
# ...             ...       ...      ...           ...                     ...
# 3421078     3421078   2266710   206209            10                       5
# 3421079     3421079   1854736   206209            11                       4
# 3421080     3421080    626363   206209            12                       1
# 3421081     3421081   2977660   206209            13                       1
# 3421082     3421082    272231   206209            14                       6
#
# ...

# %%
df_ords_first_order = df_ords[df_ords['order_number'] == 1]

# %%
df_ords_first_order
# Out:
#          Unnamed: 0  order_id  user_id  order_number  orders_day_of_the_week  \
# 0                 0   2539329        1             1                       2
# 11               11   2168274        2             1                       2
# 26               26   1374495        3             1                       1
# 39               39   3343014        4             1                       6
# 45               45   2717275        5             1                       3
# ...             ...       ...      ...           ...                     ...
# 3420930     3420930    969311   206205             1                       4
# 3420934     3420934   3189322   206206             1                       3
# 3421002     3421002   2166133   206207             1                       6
# 3421019     3421019   2227043   206208             1                       1
# 3421069     3421069   3154581   206209             1                       3
#
# ...

# %% [markdown]
# # All first orders are marked with the flag.

# %% [markdown]
# # 05 CHECK FOR DUPLICATE VALUES

# %%
df_ords_dups = df_ords[df_ords.duplicated()]

# %%
df_ords_dups
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, order_id, user_id, order_number, orders_day_of_the_week, order_hour_of_day, days_since_prior_order, First_order]
# Index: []

# %% [markdown]
# # There are no duplicated records in the ords Dataframe

# %% [markdown]
# # 06 EXPORT THE CLEANED DATAFRAMES

# %%
df_ords.to_csv(os.path.join(path, '02.Data', 'Prepared Data', 'orders_cleaned.csv'))

# %%
df_prods_clean_no_dups.to_csv(os.path.join(path, '02.Data', 'Prepared data', 'product_cleaned.csv'))
